# %%
import pandas as pd

# %% [markdown]
# Učitavanje dataseta

# %%
df = pd.read_csv("apple_products.csv")

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# Prikazati prvih 5 redova dataseta

# %% [markdown]
# metoda za prikaz prvih 5 redova - po defaultu

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.head(10)
# Out:
#                                         Product Name  \
# 0                  APPLE iPhone 8 Plus (Gold, 64 GB)
# 1           APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2               APPLE iPhone 8 Plus (Silver, 256 GB)
# 3                    APPLE iPhone 8 (Silver, 256 GB)
# 4                      APPLE iPhone 8 (Gold, 256 GB)
# 5                APPLE iPhone 8 Plus (Silver, 64 GB)
# 6            APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                APPLE iPhone 8 (Space Grey, 256 GB)
# 8                APPLE iPhone XS Max (Silver, 64 GB)
# 9  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# Prikazati zadnjih 5 redova dataseta

# %%
df.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %% [markdown]
# Brisanje kolone

# %%
del df['Product URL']

# %%
df
# Out:
#                                 Product Name  Brand  Sale Price    Mrp  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Apple       49900  49900
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple       84900  84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple       84900  84900
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple       77000  77000
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple       77000  77000
# ..                                       ...    ...         ...    ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple       29999  39900
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple       46999  54900
# 59            APPLE iPhone 11 (White, 64 GB)  Apple       46999  54900
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple       46999  54900
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple       46999  54900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  \
# ...

# %%
del df["Upc"]

# %%
df
# Out:
#                                 Product Name  Brand  Sale Price    Mrp  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Apple       49900  49900
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple       84900  84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple       84900  84900
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple       77000  77000
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple       77000  77000
# ..                                       ...    ...         ...    ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple       29999  39900
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple       46999  54900
# 59            APPLE iPhone 11 (White, 64 GB)  Apple       46999  54900
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple       46999  54900
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple       46999  54900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  Star Rating  \
# ...

# %% [markdown]
# Ispis svih kolona

# %%
lista_kolona = list(df.columns)

lista_kolona
# Out:
# ['Product Name',
#  'Brand',
#  'Sale Price',
#  'Mrp',
#  'Discount Percentage',
#  'Number Of Ratings',
#  'Number Of Reviews',
#  'Star Rating',
#  'Ram']

# %% [markdown]
# Smještanje imena kolona u listu

# %%
df.values
# Out:
# array([['APPLE iPhone 8 Plus (Gold, 64 GB)', 'Apple', 49900, 49900, 0,
#         3431, 356, 4.6, '2 GB'],
#        ['APPLE iPhone 8 Plus (Space Grey, 256 GB)', 'Apple', 84900,
#         84900, 0, 3431, 356, 4.6, '2 GB'],
#        ['APPLE iPhone 8 Plus (Silver, 256 GB)', 'Apple', 84900, 84900, 0,
#         3431, 356, 4.6, '2 GB'],
#        ['APPLE iPhone 8 (Silver, 256 GB)', 'Apple', 77000, 77000, 0,
#         11202, 794, 4.5, '2 GB'],
#        ['APPLE iPhone 8 (Gold, 256 GB)', 'Apple', 77000, 77000, 0, 11202,
#         794, 4.5, '2 GB'],
#        ['APPLE iPhone 8 Plus (Silver, 64 GB)', 'Apple', 49900, 49900, 0,
#         3431, 356, 4.6, '2 GB'],
#        ['APPLE iPhone 8 Plus (Space Grey, 64 GB)', 'Apple', 49900, 49900,
#         0, 3431, 356, 4.6, '2 GB'],
#        ['APPLE iPhone 8 (Space Grey, 256 GB)', 'Apple', 77000, 77000, 0,
#         11202, 794, 4.5, '2 GB'],
#        ['APPLE iPhone XS Max (Silver, 64 GB)', 'Apple', 89900, 89900, 0,
#         1454, 149, 4.6, '4 GB'],
# ...

# %% [markdown]
# Ispis svih vrijednosti

# %% [markdown]
# Provjera jedinstvenih vrijednosti za kolonu Brand i Ram

# %%
df['Brand'].unique()
# Out:
# array(['Apple'], dtype=object)

# %%
df['Ram'].unique()
# Out:
# array(['2 GB', '4 GB', '3 GB', '6 GB'], dtype=object)

# %% [markdown]
# Provjeriti da li se u datasetu nalazi 'APPLE iPhone 11 (Black, 64 GB)' i Number of Reviews = 8161

# %%
df.isin(['APPLE iPhone 11 (Black, 64 GB)'])
# Out:
#     Product Name  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False  False       False  False                False
# 1          False  False       False  False                False
# 2          False  False       False  False                False
# 3          False  False       False  False                False
# 4          False  False       False  False                False
# ..           ...    ...         ...    ...                  ...
# 57         False  False       False  False                False
# 58         False  False       False  False                False
# 59         False  False       False  False                False
# 60          True  False       False  False                False
# 61         False  False       False  False                False
#
#     Number Of Ratings  Number Of Reviews  Star Rating    Ram
# 0               False              False        False  False
# 1               False              False        False  False
# ...

# %%
df.isin([8161])
# Out:
#     Product Name  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False  False       False  False                False
# 1          False  False       False  False                False
# 2          False  False       False  False                False
# 3          False  False       False  False                False
# 4          False  False       False  False                False
# ..           ...    ...         ...    ...                  ...
# 57         False  False       False  False                False
# 58         False  False       False  False                False
# 59         False  False       False  False                False
# 60         False  False       False  False                False
# 61         False  False       False  False                False
#
#     Number Of Ratings  Number Of Reviews  Star Rating    Ram
# 0               False              False        False  False
# 1               False              False        False  False
# ...

# %% [markdown]
# Provjera da li ima NaN vrijednostu u Mrp koloni, i ako ima koliko ih ima

# %%
df.isnull()
# Out:
#     Product Name  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False  False       False  False                False
# 1          False  False       False  False                False
# 2          False  False       False  False                False
# 3          False  False       False  False                False
# 4          False  False       False  False                False
# ..           ...    ...         ...    ...                  ...
# 57         False  False       False  False                False
# 58         False  False       False  False                False
# 59         False  False       False  False                False
# 60         False  False       False  False                False
# 61         False  False       False  False                False
#
#     Number Of Ratings  Number Of Reviews  Star Rating    Ram
# 0               False              False        False  False
# 1               False              False        False  False
# ...

# %% [markdown]
# ### Filtriranje

# %% [markdown]
# Ispisati sve redove iz dataseta koji imaju Discount Percentage veći od 20%

# %%
df[df['Discount Percentage']>20]
# Out:
#                                    Product Name  Brand  Sale Price     Mrp  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)  Apple       74999  106600
# 52               APPLE iPhone SE (White, 64 GB)  Apple       29999   39900
# 53              APPLE iPhone SE (Black, 128 GB)  Apple       34999   44900
# 54              APPLE iPhone SE (White, 128 GB)  Apple       34999   44900
# 55                APPLE iPhone SE (Red, 128 GB)  Apple       34999   44900
# 57               APPLE iPhone SE (Black, 64 GB)  Apple       29999   39900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  Star Rating  \
# 18                   29               7088                523          4.6
# 52                   24              95807               8154          4.5
# 53                   22              95909               8161          4.5
# 54                   22              95807               8154          4.5
# ...

# %% [markdown]
# Naći sumu cijena "Sale Price" za produkte koji imaju Discount Percentage veći od 20%

# %%
lista = []
if [df[df['Discount Percentage']>20]]:
    lista = df['Sale Price']

lista
sum(lista)
# Out:
# 4964581

# %% [markdown]
# Provjeriti da li je Mrp sa Discount Percentage veći od Sale Price

# %%
df[df['Mrp'] > df['Sale Price']]
# Out:
#                                          Product Name  Brand  Sale Price  \
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...  Apple       41999
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...  Apple       39999
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...  Apple       41999
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...  Apple       41999
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...  Apple       41999
# 18        APPLE iPhone 11 Pro (Midnight Green, 64 GB)  Apple       74999
# 19           APPLE iPhone 11 Pro (Space Grey, 512 GB)  Apple      117900
# 21       APPLE iPhone 11 Pro (Midnight Green, 512 GB)  Apple      117900
# 22           APPLE iPhone 11 Pro (Space Grey, 256 GB)  Apple       99900
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...  Apple       44999
# 24               APPLE iPhone 12 Pro (Silver, 512 GB)  Apple      140900
# 25     APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)  Apple      130900
# ...
