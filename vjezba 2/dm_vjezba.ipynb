# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("apple_products.csv")

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df['Sale Price'].idxmin()
# Out:
# 52

# %%
int(df.loc[52]['Sale Price'])

df.loc[52]["Sale Price"]
# Out:
# np.float64(0.31509326654099995)

# %%
int(df.loc[df['Sale Price'].idxmax()]['Sale Price'])

df.loc[df["Sale Price"].idxmax()]["Sale Price"]
# Out:
# np.float64(1.4799373731)

# %%
df.drop([0], inplace= True)
# Out:
#                                 Product Name  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# 5        APPLE iPhone 8 Plus (Silver, 64 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ...

# %%
#df.drop(['Product URL'], axis=1, inplace= True)

# %%
df.drop(columns=["Product URL"], inplace= True)
# Out:
#                                 Product Name  Brand  Sale Price    Mrp  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Apple       49900  49900
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple       84900  84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple       84900  84900
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple       77000  77000
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple       77000  77000
# ..                                       ...    ...         ...    ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple       29999  39900
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple       46999  54900
# 59            APPLE iPhone 11 (White, 64 GB)  Apple       46999  54900
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple       46999  54900
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple       46999  54900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  \
# ...

# %%
df["Sale Price"] = df["Sale Price"].apply(lambda x : x * 0.0219)

df["Mrp"] = df["Mrp"].apply(lambda x : x * 0.0219)

# %% [markdown]
# Srednja Vrijednost

# %%
df['Sale Price'].mean()

df['Mrp'].mean()
# Out:
# np.float64(1928.4716129032252)

# %% [markdown]
# Funkcija Statiske - daje opsti opis tabele

# %%
df.describe()
# Out:
#        Sale Price          Mrp  Discount Percentage  Number Of Ratings  \
# count   62.000000    62.000000            62.000000          62.000000
# mean    38.404237  1928.471613             9.951613       22420.403226
# std     16.455633   760.561281             7.608079       33768.589550
# min     14.387820   873.810000             0.000000         542.000000
# 25%     23.932539  1202.310000             6.000000         740.000000
# 50%     36.402399  1749.810000            10.000000        2101.000000
# 75%     56.162331  2648.805000            14.000000       43470.000000
# max     67.577049  3282.810000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# 75%          3331.000000     4.600000
# ...

# %% [markdown]
# Sortiranje Vrijednosti

# %%
df.sort_values(by='Sale Price', ascending= False)
# Out:
#                                         Product Name  Brand  Sale Price  \
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)  Apple    1.479937
# 41        APPLE iPhone 12 Pro (Pacific Blue, 512 GB)  Apple    1.479937
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)  Apple    1.385406
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)  Apple    1.385406
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)  Apple    1.374903
# ..                                               ...    ...         ...
# 53                   APPLE iPhone SE (Black, 128 GB)  Apple    0.367611
# 55                     APPLE iPhone SE (Red, 128 GB)  Apple    0.367611
# 54                   APPLE iPhone SE (White, 128 GB)  Apple    0.367611
# 52                    APPLE iPhone SE (White, 64 GB)  Apple    0.315093
# 57                    APPLE iPhone SE (Black, 64 GB)  Apple    0.315093
#
#           Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# ...

# %%
df_corr = df.drop(columns=['Product Name', 'Brand'])
# Out:
#     Sale Price        Mrp  Discount Percentage  Number Of Ratings  \
# 0     0.524123  23.932539                    0               3431
# 1     0.891744  40.718889                    0               3431
# 2     0.891744  40.718889                    0               3431
# 3     0.808766  36.929970                    0              11202
# 4     0.808766  36.929970                    0              11202
# ..         ...        ...                  ...                ...
# 57    0.315093  19.136439                   24              95909
# 58    0.493652  26.330589                   14              43470
# 59    0.493652  26.330589                   14              43470
# 60    0.493652  26.330589                   14              43470
# 61    0.493652  26.330589                   14              43470
#
#     Number Of Reviews               Upc  Star Rating   Ram
# 0                 356  MOBEXRGV7EHHTGUH          4.6  2 GB
# ...

# %%
df_corr = df.drop(columns=['Upc'])

# %%
df_corr['Ram'] = df_corr['Ram'].apply(lambda x : x[0])
# Out:
#                                 Product Name  Brand  Sale Price        Mrp  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Apple    0.524123  23.932539
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple    0.891744  40.718889
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple    0.891744  40.718889
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple    0.808766  36.929970
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple    0.808766  36.929970
# ..                                       ...    ...         ...        ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple    0.315093  19.136439
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple    0.493652  26.330589
# 59            APPLE iPhone 11 (White, 64 GB)  Apple    0.493652  26.330589
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple    0.493652  26.330589
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple    0.493652  26.330589
#
# ...

# %%
df_corr.corr
# Out:
# <bound method DataFrame.corr of                                 Product Name  Brand  Sale Price        Mrp  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Apple    0.524123  23.932539
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple    0.891744  40.718889
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple    0.891744  40.718889
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple    0.808766  36.929970
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple    0.808766  36.929970
# ..                                       ...    ...         ...        ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple    0.315093  19.136439
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple    0.493652  26.330589
# 59            APPLE iPhone 11 (White, 64 GB)  Apple    0.493652  26.330589
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple    0.493652  26.330589
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple    0.493652  26.330589
#
# ...

# %%
df = pd.read_csv("apple_products.csv")
df.drop(['Product URL',"Upc"], axis = 1, inplace= True)

df1 = df.drop([0,1,2,3])
df_nan = df.add(df1)
df_nan
# Out:
#                                          Product Name       Brand  Sale Price  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4   APPLE iPhone 8 (Gold, 256 GB)APPLE iPhone 8 (G...  AppleApple    154000.0
# ..                                                ...         ...         ...
# 57  APPLE iPhone SE (Black, 64 GB)APPLE iPhone SE ...  AppleApple     59998.0
# 58  APPLE iPhone 11 (Purple, 64 GB)APPLE iPhone 11...  AppleApple     93998.0
# 59  APPLE iPhone 11 (White, 64 GB)APPLE iPhone 11 ...  AppleApple     93998.0
# 60  APPLE iPhone 11 (Black, 64 GB)APPLE iPhone 11 ...  AppleApple     93998.0
# 61  APPLE iPhone 11 (Red, 64 GB)APPLE iPhone 11 (R...  AppleApple     93998.0
#
# ...

# %%
df_nan.dropna(how = )
