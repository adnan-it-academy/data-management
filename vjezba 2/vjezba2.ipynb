# %%
import pandas as pd

# %%
df = pd.read_csv("apple_products.csv")

# %%
df["Sale Price"].idxmin()
# Out:
# 52

# %%
df.loc[52]["Sale Price"]
# Out:
# np.int64(29999)

# %%
df["Sale Price"].idxmax()
# Out:
# 24

# %%
df.loc[24]
# Out:
# Product Name                        APPLE iPhone 12 Pro (Silver, 512 GB)
# Product URL            https://www.flipkart.com/apple-iphone-12-pro-s...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                    6
# Number Of Ratings                                                    542
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZ5UY6ZBVA
# Star Rating                                                          4.5
# Ram                                                                 4 GB
# Name: 24, dtype: object

# %%
df.loc[24]["Sale Price"]
# Out:
# np.int64(140900)

# %%
df.drop([0])
# Out:
#                                 Product Name  Brand  Sale Price    Mrp  \
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Apple   1859.3100  84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Apple   1859.3100  84900
# 3            APPLE iPhone 8 (Silver, 256 GB)  Apple   1686.3000  77000
# 4              APPLE iPhone 8 (Gold, 256 GB)  Apple   1686.3000  77000
# 5        APPLE iPhone 8 Plus (Silver, 64 GB)  Apple   1092.8100  49900
# ..                                       ...    ...         ...    ...
# 57            APPLE iPhone SE (Black, 64 GB)  Apple    656.9781  39900
# 58           APPLE iPhone 11 (Purple, 64 GB)  Apple   1029.2781  54900
# 59            APPLE iPhone 11 (White, 64 GB)  Apple   1029.2781  54900
# 60            APPLE iPhone 11 (Black, 64 GB)  Apple   1029.2781  54900
# 61              APPLE iPhone 11 (Red, 64 GB)  Apple   1029.2781  54900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  \
# ...

# %%
df.drop(["Product URL"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.drop(["Product URL"], axis=1)
#
# File c:\Users\Python\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.drop(["Product URL"], axis=1, inplace=True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop(["Product URL"], axis=1, inplace=True )
#
# File c:\Users\Python\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
def konverzija_KM(x):
    return x*0.0219

df["Sale Price"] = df["Sale Price"].apply(konverzija_KM)

# %%
df["Sale Price"]
# Out:
# 0     1092.8100
# 1     1859.3100
# 2     1859.3100
# 3     1686.3000
# 4     1686.3000
#         ...
# 57     656.9781
# 58    1029.2781
# 59    1029.2781
# 60    1029.2781
# 61    1029.2781
# Name: Sale Price, Length: 62, dtype: float64

# %%
df["Sale Price"].mean()
# Out:
# np.float64(1753.618127419354)

# %%
df["Mrp"].mean()
# Out:
# np.float64(88058.06451612903)

# %%
df.describe()

# %%
df.sort_values(by="Sale Price", ascending=False) #ascending ako hocemo od veceg ka manjem
# Out:
#                                         Product Name  Brand  Sale Price  \
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)  Apple      140900
# 41        APPLE iPhone 12 Pro (Pacific Blue, 512 GB)  Apple      140900
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)  Apple      131900
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)  Apple      131900
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)  Apple      130900
# ..                                               ...    ...         ...
# 53                   APPLE iPhone SE (Black, 128 GB)  Apple       34999
# 55                     APPLE iPhone SE (Red, 128 GB)  Apple       34999
# 54                   APPLE iPhone SE (White, 128 GB)  Apple       34999
# 52                    APPLE iPhone SE (White, 64 GB)  Apple       29999
# 57                    APPLE iPhone SE (Black, 64 GB)  Apple       29999
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# ...

# %%
df_corr = df.drop(["Product Name", "Brand"], axis=1)
df_corr
# Out:
#     Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# 0        49900  49900                    0               3431
# 1        84900  84900                    0               3431
# 2        84900  84900                    0               3431
# 3        77000  77000                    0              11202
# 4        77000  77000                    0              11202
# ..         ...    ...                  ...                ...
# 57       29999  39900                   24              95909
# 58       46999  54900                   14              43470
# 59       46999  54900                   14              43470
# 60       46999  54900                   14              43470
# 61       46999  54900                   14              43470
#
#     Number Of Reviews  Star Rating   Ram
# 0                 356          4.6  2 GB
# 1                 356          4.6  2 GB
# 2                 356          4.6  2 GB
# 3                 794          4.5  2 GB
# ...

# %%
def remove_GB(x):
    return x[0]

df_corr["Ram"]= df_corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2108\3184684144.py in ?()
#       1 def remove_GB(x):
#       2     return x[0]
#       3
# ----> 4 df_corr["Ram"]= df_corr
#
# c:\Users\Python\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# c:\Users\Python\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4455
# ...

# %%
df = pd.read_csv("apple_products.csv")
df.drop(["Product URL", "Upc"],axis=1, inplace=True)

df1 = df.drop([0,1,2,3])
df_nan = df.add(df1)
df_nan
# Out:
#                                          Product Name       Brand  Sale Price  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4   APPLE iPhone 8 (Gold, 256 GB)APPLE iPhone 8 (G...  AppleApple    154000.0
# ..                                                ...         ...         ...
# 57  APPLE iPhone SE (Black, 64 GB)APPLE iPhone SE ...  AppleApple     59998.0
# 58  APPLE iPhone 11 (Purple, 64 GB)APPLE iPhone 11...  AppleApple     93998.0
# 59  APPLE iPhone 11 (White, 64 GB)APPLE iPhone 11 ...  AppleApple     93998.0
# 60  APPLE iPhone 11 (Black, 64 GB)APPLE iPhone 11 ...  AppleApple     93998.0
# 61  APPLE iPhone 11 (Red, 64 GB)APPLE iPhone 11 (R...  AppleApple     93998.0
#
# ...
