# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 660.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 464.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 4.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.5 MB 6.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/11.5 MB 5.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/11.5 MB 6.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.5 MB 7.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.5 MB 7.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 8.3 MB/s eta 0:00:02
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      -------------------------------------  102.4/104.6 kB 3.0 MB/s eta 0:00:01
#      -------------------------------------  102.4/104.6 kB 3.0 MB/s eta 0:00:01
#      -------------------------------------- 104.6/104.6 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.1 MB 14.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.6/8.1 MB 9.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.1 MB 7.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.4/8.1 MB 7.9 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.1 MB 8.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.1 MB 9.3 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/8.1 MB 9.5 MB/s eta 0:00:01
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/294.9 kB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB 1.3 MB/s eta 0:00:01
#      --------------------------------- ------ 51.2/60.8 kB 1.3 MB/s eta 0:00:01
#      --------------------------------- ------ 51.2/60.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 293.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.1 MB 3.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.1 MB 5.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.1 MB 5.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.1 MB 6.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.1 MB 7.2 MB/s eta 0:00:02
# ...

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    -------------- ------------------------- 92.2/250.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('C:/Users/Alma/Desktop/Data-visualization/data-visualization/vjezba4/Sleep_health_and_lifestyle_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
df.notnull().sum()
# Out:
# Person ID                  374
# Gender                     374
# Age                        374
# Occupation                 374
# Sleep Duration             374
# Quality of Sleep           374
# Physical Activity Level    374
# Stress Level               374
# BMI Category               374
# Blood Pressure             374
# Heart Rate                 374
# Daily Steps                374
# Sleep Disorder             155
# dtype: int64

# %% [markdown]
# U datasetu se nalazi 375 osoba i broj osoba po godinama iznosi:

# %%
df['Age'].value_counts()
# Out:
# Age
# 43    34
# 44    30
# 37    20
# 38    20
# 50    20
# 31    18
# 32    17
# 53    17
# 59    16
# 39    15
# 45    14
# 33    13
# 29    13
# 30    13
# 36    12
# 35    12
# 41    12
# 49    11
# 42     9
# 57     9
# 52     9
# 51     8
# 54     7
# 58     6
# 28     5
# 40     4
# 48     3
# 55     2
# 34     2
# 56     2
# 27     1
# Name: count, dtype: int64

# %% [markdown]
# Prosječna starost grupe je 42 godine

# %%
df['Age'].mean()
# Out:
# np.float64(42.18449197860963)

# %% [markdown]
# Broj osoba po zanimanjima

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %% [markdown]
# Prosječno trajanje sna

# %%
df['Sleep Duration'].mean()
# Out:
# np.float64(7.132085561497325)

# %% [markdown]
# Osoba sa najkraćom dužinom sna

# %%
df.loc[df['Sleep Duration'].idxmin()]
# Out:
# Person ID                           81
# Gender                          Female
# Age                                 34
# Occupation                   Scientist
# Sleep Duration                     5.8
# Quality of Sleep                     4
# Physical Activity Level             32
# Stress Level                         8
# BMI Category                Overweight
# Blood Pressure                  131/86
# Heart Rate                          81
# Daily Steps                       5200
# Sleep Disorder             Sleep Apnea
# Name: 80, dtype: object

# %% [markdown]
# Osoba sa najdužim trajanjem sna

# %%
df.loc[df['Sleep Duration'].idxmax()]
# Out:
# Person ID                       299
# Gender                       Female
# Age                              51
# Occupation                 Engineer
# Sleep Duration                  8.5
# Quality of Sleep                  9
# Physical Activity Level          30
# Stress Level                      3
# BMI Category                 Normal
# Blood Pressure               125/80
# Heart Rate                       65
# Daily Steps                    5000
# Sleep Disorder                  NaN
# Name: 298, dtype: object

# %% [markdown]
# Broj osoba po polu sa problemima sa spavanjem

# %%
df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %%
df['BMI Category'].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %% [markdown]
# Raspored unutar seta po polu

# %%
df["Gender"].value_counts(normalize=True)*100
# Out:
# Gender
# Male      50.534759
# Female    49.465241
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x='BMI Category', palette='pastel')
# Out:
# C:\Users\Alma\AppData\Local\Temp\ipykernel_6224\217658469.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='BMI Category', palette='pastel')
# <Axes: xlabel='BMI Category', ylabel='count'>

# %%
sns.countplot(y='Occupation', data=df)
# Out:
# <Axes: xlabel='count', ylabel='Occupation'>

# %%
sns.countplot(x='Sleep Disorder', data = df, hue='Gender')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
sns.boxplot(x='BMI Category', y='Stress Level', data=df)
# Out:
# <Axes: xlabel='BMI Category', ylabel='Stress Level'>

# %%
sns.histplot(data=df, x='Physical Activity Level')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Count'>

# %%
df['Physical Activity Level'].value_counts()
# Out:
# Physical Activity Level
# 60    70
# 30    68
# 45    68
# 75    67
# 90    67
# 40     6
# 55     6
# 35     4
# 50     4
# 70     3
# 42     2
# 32     2
# 80     2
# 65     2
# 85     2
# 47     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
cor_m = df[['Age', 'Sleep Duration', 'Quality of Sleep', 'Stress Level', 'Heart Rate', 'Daily Steps']].corr()

# %%
sns.heatmap(data=cor_m, annot=True)
# Out:
# <Axes: >

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Alma\AppData\Local\Temp\ipykernel_6224\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df['Sleep Duration'].values.reshape(-1,1)
y = df['Stress Level'].values

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
sns.regplot(x=X, y=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = lr.predict(X_test)

# %%
score = r2_score(y_test, y_prediction)
print('r2 = ', score)
# Out:
# r2 =  0.6768383443984058

# %%
print('MSE= ', mean_squared_error(y_test, y_prediction))
# Out:
# MSE=  1.028372201825517
